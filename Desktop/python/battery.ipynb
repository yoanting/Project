# %%
import numpy as np
from scipy.integrate import odeint
import math
from matplotlib import pyplot as plt

# %%
L = 2*(10**-5) # m
cat_conductivity = 300 # Sm^-1
specific_area = 2.31e6 # m-1
i_slow = (0.000017945811609164856 + 0.000018038360660111245 + 0.000017995624361842263)/3  # Am^-2
i_fast = (0.009838027698240602 + 0.009849498195788928 + 0.009856505279562468)/3 # Am^-2
i_app = 0.5 #Am^-2
n = 101
t_tot = 41035
t = np.linspace(0,t_tot,n)

y = t / t_tot  

Si = 50
i_n2 = np.zeros(len(y))

def i_n(y):
    for i in range(len(y)):
        i_n2[i] = ((i_fast - i_slow)/2)*(np.tanh(Si*(y[i]-.5))) + ((i_fast + i_slow)/2)
    return i_n2

#volume_fraction_cat = 0.0963
#porosity = 0.837
#electrolyte_conductivity = 0.42
#cat_transfer_coe = 0.5
#full_capacity_chevrel = 128.8




plt.plot(y,i_n(y))
print(i_n(y))
# Out:
# [1.79932655e-05 1.79932655e-05 1.79932655e-05 1.79932655e-05
#  1.79932655e-05 1.79932655e-05 1.79932655e-05 1.79932655e-05
#  1.79932655e-05 1.79932655e-05 1.79932655e-05 1.79932655e-05
#  1.79932655e-05 1.79932655e-05 1.79932655e-05 1.79932655e-05
#  1.79932655e-05 1.79932655e-05 1.79932655e-05 1.79932655e-05
#  1.79932655e-05 1.79932655e-05 1.79932656e-05 1.79932656e-05
#  1.79932656e-05 1.79932657e-05 1.79932659e-05 1.79932666e-05
#  1.79932683e-05 1.79932730e-05 1.79932858e-05 1.79933206e-05
#  1.79934153e-05 1.79936725e-05 1.79943718e-05 1.79962726e-05
#  1.80014395e-05 1.80154846e-05 1.80536629e-05 1.81574408e-05
#  1.84395274e-05 1.92062363e-05 2.12897631e-05 2.69489144e-05
#  4.22991935e-05 8.37841047e-05 1.94798017e-04 4.84190411e-04
#  1.18976003e-03 2.66169204e-03 4.93300183e-03 7.20431161e-03
#  8.67624363e-03 9.38181325e-03 9.67120564e-03 9.78221955e-03
#  9.82370446e-03 9.83905474e-03 9.84471389e-03 9.84679742e-03
# ...

# %%
specific_area = float(2.31e6) 
cat_conductivity = float(300)
i_app = 0.5
n = 101
L = 2*(10**-5)


i=[1.79932655e-05, 1.79932655e-05, 1.79932655e-05, 1.79932655e-05,
 1.79932655e-05, 1.79932655e-05, 1.79932655e-05, 1.79932655e-05,
 1.79932655e-05, 1.79932655e-05, 1.79932655e-05, 1.79932655e-05,
 1.79932655e-05, 1.79932655e-05, 1.79932655e-05, 1.79932655e-05,
 1.79932655e-05, 1.79932655e-05, 1.79932655e-05, 1.79932655e-05,
 1.79932655e-05, 1.79932655e-05, 1.79932656e-05, 1.79932656e-05,
 1.79932656e-05, 1.79932657e-05, 1.79932659e-05, 1.79932666e-05,
 1.79932683e-05, 1.79932730e-05, 1.79932858e-05, 1.79933206e-05,
 1.79934153e-05, 1.79936725e-05, 1.79943718e-05, 1.79962726e-05,
 1.80014395e-05, 1.80154846e-05, 1.80536629e-05, 1.81574408e-05,
 1.84395274e-05, 1.92062363e-05, 2.12897631e-05, 2.69489144e-05,
 4.22991935e-05, 8.37841047e-05, 1.94798017e-04, 4.84190411e-04,
 1.18976003e-03, 2.66169204e-03, 4.93300183e-03, 7.20431161e-03,
 8.67624363e-03, 9.38181325e-03, 9.67120564e-03, 9.78221955e-03,
 9.82370446e-03, 9.83905474e-03, 9.84471389e-03, 9.84679742e-03,
 9.84756413e-03, 9.84784622e-03, 9.84794999e-03, 9.84798817e-03,
 9.84800222e-03, 9.84800738e-03, 9.84800928e-03, 9.84800998e-03,
 9.84801024e-03, 9.84801034e-03, 9.84801037e-03, 9.84801038e-03,
 9.84801039e-03, 9.84801039e-03, 9.84801039e-03, 9.84801039e-03,
 9.84801039e-03, 9.84801039e-03, 9.84801039e-03, 9.84801039e-03,
 9.84801039e-03, 9.84801039e-03, 9.84801039e-03, 9.84801039e-03,
 9.84801039e-03, 9.84801039e-03, 9.84801039e-03, 9.84801039e-03,
 9.84801039e-03, 9.84801039e-03, 9.84801039e-03, 9.84801039e-03,
 9.84801039e-03, 9.84801039e-03, 9.84801039e-03, 9.84801039e-03,
 9.84801039e-03, 9.84801039e-03, 9.84801039e-03, 9.84801039e-03,
 9.84801039e-03]

def u2fun(u2, x):
    du2dx =float(( specific_area * i )/ cat_conductivity)
    return du2dx

x = np.linspace(0,L,n)
u2_0 = i_app / (-cat_conductivity)

for i in x:
    uu2 = odeint(u2fun , u2_0  ,x)
    ##print(uu2)

plt.plot(x,uu2)
plt.show()

def u1fun(u1, t):
    du1dy =u1
    return du1dy

u1_L = 10
x = np.linspace(0,L,n)
for i in x:
    uu1= odeint(u1fun , u1_L  ,x)
    ##print(uu1)

plt.plot(x,uu1)
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

SX, ST = np.meshgrid(y, i)
ax.plot_surface(SX, ST, uu1, cmap='jet')
ax.set_xlabel('y')
ax.set_ylabel('i')
ax.set_zlabel('uu1')
ax.view_init(elev=25, azim=-10)

# %%
specific_area = float(2.31e6) 
cat_conductivity = float(300)
i_app = 0.5
n = 101
L = 2*(10**-5)


i=[1.79932655e-05, 1.79932655e-05, 1.79932655e-05, 1.79932655e-05,
 1.79932655e-05, 1.79932655e-05, 1.79932655e-05, 1.79932655e-05,
 1.79932655e-05, 1.79932655e-05, 1.79932655e-05, 1.79932655e-05,
 1.79932655e-05, 1.79932655e-05, 1.79932655e-05, 1.79932655e-05,
 1.79932655e-05, 1.79932655e-05, 1.79932655e-05, 1.79932655e-05,
 1.79932655e-05, 1.79932655e-05, 1.79932656e-05, 1.79932656e-05,
 1.79932656e-05, 1.79932657e-05, 1.79932659e-05, 1.79932666e-05,
 1.79932683e-05, 1.79932730e-05, 1.79932858e-05, 1.79933206e-05,
 1.79934153e-05, 1.79936725e-05, 1.79943718e-05, 1.79962726e-05,
 1.80014395e-05, 1.80154846e-05, 1.80536629e-05, 1.81574408e-05,
 1.84395274e-05, 1.92062363e-05, 2.12897631e-05, 2.69489144e-05,
 4.22991935e-05, 8.37841047e-05, 1.94798017e-04, 4.84190411e-04,
 1.18976003e-03, 2.66169204e-03, 4.93300183e-03, 7.20431161e-03,
 8.67624363e-03, 9.38181325e-03, 9.67120564e-03, 9.78221955e-03,
 9.82370446e-03, 9.83905474e-03, 9.84471389e-03, 9.84679742e-03,
 9.84756413e-03, 9.84784622e-03, 9.84794999e-03, 9.84798817e-03,
 9.84800222e-03, 9.84800738e-03, 9.84800928e-03, 9.84800998e-03,
 9.84801024e-03, 9.84801034e-03, 9.84801037e-03, 9.84801038e-03,
 9.84801039e-03, 9.84801039e-03, 9.84801039e-03, 9.84801039e-03,
 9.84801039e-03, 9.84801039e-03, 9.84801039e-03, 9.84801039e-03,
 9.84801039e-03, 9.84801039e-03, 9.84801039e-03, 9.84801039e-03,
 9.84801039e-03, 9.84801039e-03, 9.84801039e-03, 9.84801039e-03,
 9.84801039e-03, 9.84801039e-03, 9.84801039e-03, 9.84801039e-03,
 9.84801039e-03, 9.84801039e-03, 9.84801039e-03, 9.84801039e-03,
 9.84801039e-03, 9.84801039e-03, 9.84801039e-03, 9.84801039e-03,
 9.84801039e-03]

def u2fun(u2, x):
    du2dx =float(( specific_area * i )/ cat_conductivity)
    return du2dx

x = np.linspace(0,L,n)
u2_0 = i_app / (-cat_conductivity)

for i in x:
    uu2 = odeint(u2fun , u2_0  ,x)
    ##print(uu2)

plt.plot(x,uu2)
plt.show()

def u1fun(u1, t):
    du1dy =u1
    return du1dy

u1_L = 10
x = np.linspace(0,L,n)
for i in x:
    uu1= odeint(u1fun , u1_L  ,x)
    ##print(uu1)

plt.plot(x,uu1)
plt.show()

# %%
### ignore

def fun(U,y):
    u1, u2 = U
    du1dy = u2
    du2dy = specific_area * i_n(y) / cat_conductivity
    
   # dfdy = np.stack((du1dy,du2dy))
     
    return [du1dy, du2dy]


u2_0 = i_app / (-cat_conductivity)
u2_L = 0
    
for i in range (n):
    U = odeint(fun, [u2_0, u2_L], y )
    
print (U)

def plot_results(y, U):
    plt.plot(y, U[:,0])
    plt.plot([0,L],[0,0], 'ro') 
    plt.xlim(0,L)
    plt.xlabel('L')
    plt.ylabel('$u_1$')

plot_results(y, U)
                

plt.ylim(-0.01,.00001)


for i in range (n): 
    U = odeint(fun, [u2_0, u2_L], i )
    
print(U)

# %%
from scipy.optimize import fsolve

u2_0 = i_app / (-cat_conductivity) # known

def objective(u2_0):
    U = odeint(fun, [u2_0, u2_L], y)
    return U[-1,0]

u2_L, = fsolve(objective, 1.0)
print("Optimized u1 is {}".format(u2_0))

# now solve with optimal u2_0
U = odeint(fun, [u2_0, u2_L], y)

plot_results(y, U)
plt.show()
